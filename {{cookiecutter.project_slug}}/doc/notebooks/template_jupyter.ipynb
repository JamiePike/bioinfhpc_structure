# %% [markdown]
# # {{ cookiecutter.project_name }} Notebook
# **Author:** {{ cookiecutter.author_name }}
# **Date:** 2026-06-19
#
# ---

# %%
# Quick verification of results directory
import os
print(os.listdir('../../results/latest'))
